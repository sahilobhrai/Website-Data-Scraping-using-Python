# %% [markdown]
# #### Picking a website to scrap data from: here we choose spotify data scraping

# %%
# !pip install requests --upgrade --quiet
#instaling requests library

# %%
import requests

# %%
topics_url = 'https://www.spotify.com/in-en/free/?utm_source=in-en_brand_contextual_text&utm_medium=paidsearch&utm_campaign=alwayson_asia_in_premiumbusiness_core_brand+contextual-desktop+text+exact+in-en+google&ds_rl=1270915&gclid=CjwKCAiA55mPBhBOEiwANmzoQiP3z8_9Jau4IQR_2eEx2aKuxIjzabNJWPwzitjNaUs4sjYGAUGkJBoCkO0QAvD_BwE&gclsrc=aw.ds'

# %%
response = requests.get(topics_url)

# %%
page_contents = response.text

# %%
# !pip install beautifulsoup4 --upgrade --quiet

# %%
from bs4 import BeautifulSoup

# %%
doc = BeautifulSoup(page_contents, 'html.parser')

# %%
doc
# Out:
# <!DOCTYPE html>
# ...

# %%
# !pip install pandas --upgrade --quiet

# %%
import pandas as pd

# %%
df = pd.DataFrame(doc)
df.to_html('index.html')
